# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

ORION_URL = "http://localhost:1026"
MINTAKA_URL = "http://localhost:8080"

headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/ld+json',
        'Link': '<https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

# %%
# Check Orion Context Broker version
def test_connection():
    """Check if Orion Context Broker is accessible"""
    try:
        # Send GET request to version endpoint
        response = requests.get(f"{ORION_URL}/version")
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            version_info = response.json()
            print(f"Orion Version: {version_info.get('orion version', 'Unknown')}")
            print(f"Orion-LD Version: {version_info.get('orionld version', 'Unknown')}")
        else:
            print("Failed to connect to Orion")
            
    except Exception as e:
        print(f"Connection error: {e}")

# Run the test
test_connection()
# Out:
# Status Code: 200
# Orion Version: 1.15.0-next
# Orion-LD Version: 1.4.0

# %%
# def function for entity query test

def get_entity_types():
    """Get all available entity types"""
    try:
        response = requests.get(f"{ORION_URL}/ngsi-ld/v1/types", headers=headers)
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            types_data = response.json()
                         
            return types_data
        else:
            print(f"Failed: {response.text}")
            return []
    except Exception as e:
        print(f"Error: {e}")
        return []

def get_all_entities():
    """Get all entities from Orion Context Broker"""
    try:
        # Add local=true to avoid "too broad query" error
        params = {
            "limit": 1000,
            "local": "true"
        }
        
        response = requests.get(f"{ORION_URL}/ngsi-ld/v1/entities", 
                              headers=headers, 
                              params=params)
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            entities = response.json()
            print(f"Retrieved {len(entities)} entities")
            
            # Display basic info about each entity
            for i, entity in enumerate(entities):
                print(f"\nEntity {i+1}:")
                print(f"  ID: {entity.get('id')}")
                
                # Handle type field in NGSI-LD format
                entity_type = entity.get('type')
                if isinstance(entity_type, list):
                    entity_type = entity_type[0] if entity_type else 'Unknown'
                print(f"  Type: {entity_type}")
                
                # Count attributes (exclude @context, id, type)
                excluded_keys = ['@context', 'id', 'type']
                attr_count = len([k for k in entity.keys() if k not in excluded_keys])
                print(f"  Attributes: {attr_count}")
                
                # Show @context if present
                if '@context' in entity:
                    print(f"  Context: {entity.get('@context')}")
            
            return entities
        else:
            print("Failed to get entities")
            print(f"Response: {response.text}")
            return []
            
    except Exception as e:
        print(f"Error: {e}")
        return []
    
def query_entity_by_id(entity_id):
    """Query entity by exact ID"""
    try:
        response = requests.get(f"{ORION_URL}/ngsi-ld/v1/entities/{entity_id}", 
                              headers=headers)
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            entity = response.json()          
            return entity
        else:
            print(f"Entity not found: {response.text}")
            return None
            
    except Exception as e:
        print(f"Error: {e}")
        return None

def query_entities_by_type(entity_type):
    """Query entities by type"""
    try:
        params = {
            "type": entity_type,
            "limit": 10     # limit 10 outputs
        }
        
        response = requests.get(f"{ORION_URL}/ngsi-ld/v1/entities", 
                              headers=headers, 
                              params=params)
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            entities = response.json()
            print(f"Found {len(entities)} entities of type '{entity_type}'")
            
            for i, entity in enumerate(entities):
                print(f"\nEntity {i+1}:")
                print(f"  ID: {entity.get('id')}")
                print(f"  Type: {entity.get('type')}")
            
            return entities
        else:
            print(f"Query failed: {response.text}")
            return []
            
    except Exception as e:
        print(f"Error: {e}")
        return []

def query_entities_by_attribute(attribute_name, attribute_value):
    """Query entities by attribute value"""
    try:
        params = {
            "q": f'{attribute_name}=="{attribute_value}"',
            "limit": 10
        }
        
        response = requests.get(f"{ORION_URL}/ngsi-ld/v1/entities", 
                              headers=headers, 
                              params=params)
        print(f"Status Code: {response.status_code}")
        print(f"Query: {params['q']}")
        
        if response.status_code == 200:
            entities = response.json()
            print(f"Found {len(entities)} entities with {attribute_name}={attribute_value}")
            
            for i, entity in enumerate(entities):
                print(f"\nEntity {i+1}:")
                print(f"  ID: {entity.get('id')}")
                print(f"  Type: {entity.get('type')}")
                if attribute_name in entity:
                    attr_value = entity[attribute_name]
                    if isinstance(attr_value, dict) and 'value' in attr_value:
                        print(f"  {attribute_name}: {attr_value['value']}")
                    else:
                        print(f"  {attribute_name}: {attr_value}")
            
            return entities
        else:
            print(f"Query failed: {response.text}")
            return []
            
    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
get_entity_types()
# Out:
# Status Code: 200
# {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#  'id': 'urn:ngsi-ld:EntityTypeList:a8556fc0-5b16-11f0-8183-0242ac140005',
#  'type': 'EntityTypeList',
#  'typeList': ['ChargingPoint',
#   'ChargingPointStatus',
#   'ChargingSession',
#   'ChargingSessionTest',
#   'E-Vehicle']}

# %%
get_all_entities()
# Out:
# Status Code: 200
# Retrieved 136 entities
#
# Entity 1:
#   ID: urn:ngsi-ld:ChargingPointStatus:CP_001_S_001
#   Type: ChargingPointStatus
#   Attributes: 4
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 2:
#   ID: urn:ngsi-ld:ChargingPoint:E4C-001-CP-001
#   Type: ChargingPoint
#   Attributes: 8
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 3:
#   ID: urn:ngsi-ld:E-Vehicle:EV-001
#   Type: E-Vehicle
#   Attributes: 8
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 4:
#   ID: urn:ngsi-ld:ChargingSession:session-512840826
#   Type: ChargingSession
#   Attributes: 14
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 5:
#   ID: urn:ngsi-ld:ChargingPointStatus:E4C-001-CP-001-S
#   Type: ChargingPointStatus
#   Attributes: 4
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 6:
#   ID: urn:ngsi-ld:ChargingSession:session-703497342
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 7:
#   ID: urn:ngsi-ld:ChargingSession:session-412512340
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 8:
#   ID: urn:ngsi-ld:ChargingSession:session-852888750
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 9:
#   ID: urn:ngsi-ld:ChargingSession:session-718583992
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 10:
#   ID: urn:ngsi-ld:ChargingSession:session-155986737
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 11:
#   ID: urn:ngsi-ld:ChargingSession:session-487807670
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 12:
#   ID: urn:ngsi-ld:ChargingSession:session-528124502
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 13:
#   ID: urn:ngsi-ld:ChargingSession:session-840223019
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 14:
#   ID: urn:ngsi-ld:ChargingSession:session-5101423
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 15:
#   ID: urn:ngsi-ld:ChargingSession:session-751802629
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 16:
#   ID: urn:ngsi-ld:ChargingSession:session-401415615
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 17:
#   ID: urn:ngsi-ld:ChargingSession:session-466157556
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 18:
#   ID: urn:ngsi-ld:ChargingSession:session-709813933
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 19:
#   ID: urn:ngsi-ld:ChargingSession:session-786529422
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 20:
#   ID: urn:ngsi-ld:ChargingSession:session-588947121
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 21:
#   ID: urn:ngsi-ld:ChargingSession:session-1786598
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 22:
#   ID: urn:ngsi-ld:ChargingSession:session-178095963
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 23:
#   ID: urn:ngsi-ld:ChargingSession:session-708513173
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 24:
#   ID: urn:ngsi-ld:ChargingSession:session-355075576
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 25:
#   ID: urn:ngsi-ld:ChargingSession:session-298977409
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 26:
#   ID: urn:ngsi-ld:ChargingSession:session-104180590
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 27:
#   ID: urn:ngsi-ld:ChargingSession:session-684600035
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 28:
#   ID: urn:ngsi-ld:ChargingSession:session-535619558
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 29:
#   ID: urn:ngsi-ld:ChargingSession:session-2187733
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 30:
#   ID: urn:ngsi-ld:ChargingSession:session-831634513
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 31:
#   ID: urn:ngsi-ld:ChargingSession:session-201298987
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 32:
#   ID: urn:ngsi-ld:ChargingSession:session-607042684
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 33:
#   ID: urn:ngsi-ld:ChargingSession:session-954924940
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 34:
#   ID: urn:ngsi-ld:ChargingSession:session-980061416
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 35:
#   ID: urn:ngsi-ld:ChargingSession:session-193296851
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 36:
#   ID: urn:ngsi-ld:ChargingSession:session-496286247
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 37:
#   ID: urn:ngsi-ld:ChargingSession:session-385383448
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 38:
#   ID: urn:ngsi-ld:ChargingSession:session-118530143
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 39:
#   ID: urn:ngsi-ld:ChargingSession:session-103570858
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 40:
#   ID: urn:ngsi-ld:ChargingSession:session-250404227
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 41:
#   ID: urn:ngsi-ld:ChargingSession:session-354342869
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 42:
#   ID: urn:ngsi-ld:ChargingSession:session-371361100
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 43:
#   ID: urn:ngsi-ld:ChargingSession:session-417039424
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 44:
#   ID: urn:ngsi-ld:ChargingSession:session-387624046
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 45:
#   ID: urn:ngsi-ld:ChargingSession:session-259024903
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 46:
#   ID: urn:ngsi-ld:ChargingSession:session-139884406
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 47:
#   ID: urn:ngsi-ld:ChargingSession:session-437467678
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 48:
#   ID: urn:ngsi-ld:ChargingSession:session-299380920
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 49:
#   ID: urn:ngsi-ld:ChargingSession:session-126044261
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 50:
#   ID: urn:ngsi-ld:ChargingSession:session-420491766
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 51:
#   ID: urn:ngsi-ld:ChargingSession:session-512386661
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 52:
#   ID: urn:ngsi-ld:ChargingSession:session-551911978
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 53:
#   ID: urn:ngsi-ld:ChargingSession:session-216569368
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 54:
#   ID: urn:ngsi-ld:ChargingSession:session-309596922
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 55:
#   ID: urn:ngsi-ld:ChargingSession:session-420492462
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 56:
#   ID: urn:ngsi-ld:ChargingSession:session-934441970
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 57:
#   ID: urn:ngsi-ld:ChargingSession:session-865829010
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 58:
#   ID: urn:ngsi-ld:ChargingSession:session-289018667
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 59:
#   ID: urn:ngsi-ld:ChargingSession:session-322404438
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 60:
#   ID: urn:ngsi-ld:ChargingSession:session-521952424
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 61:
#   ID: urn:ngsi-ld:ChargingSession:session-549442374
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 62:
#   ID: urn:ngsi-ld:ChargingSession:session-24354727
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 63:
#   ID: urn:ngsi-ld:ChargingSession:session-432061615
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 64:
#   ID: urn:ngsi-ld:ChargingSession:session-450698570
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 65:
#   ID: urn:ngsi-ld:ChargingSession:session-767606194
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 66:
#   ID: urn:ngsi-ld:ChargingSession:session-108164427
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 67:
#   ID: urn:ngsi-ld:ChargingSession:session-991144708
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 68:
#   ID: urn:ngsi-ld:ChargingSession:session-241391676
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 69:
#   ID: urn:ngsi-ld:ChargingSession:session-25055364
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 70:
#   ID: urn:ngsi-ld:ChargingSession:session-157744144
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 71:
#   ID: urn:ngsi-ld:ChargingSession:session-884751913
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 72:
#   ID: urn:ngsi-ld:ChargingSession:session-413377886
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 73:
#   ID: urn:ngsi-ld:ChargingSession:session-128517935
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 74:
#   ID: urn:ngsi-ld:ChargingSession:session-990464522
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 75:
#   ID: urn:ngsi-ld:ChargingSession:session-434505646
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 76:
#   ID: urn:ngsi-ld:ChargingSession:session-108167276
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 77:
#   ID: urn:ngsi-ld:ChargingSession:session-976599440
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 78:
#   ID: urn:ngsi-ld:ChargingSession:session-920623857
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 79:
#   ID: urn:ngsi-ld:ChargingSession:session-305034411
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 80:
#   ID: urn:ngsi-ld:ChargingSession:session-574616000
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 81:
#   ID: urn:ngsi-ld:ChargingSession:session-230012903
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 82:
#   ID: urn:ngsi-ld:ChargingSession:session-923619105
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 83:
#   ID: urn:ngsi-ld:ChargingSession:session-92647102
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 84:
#   ID: urn:ngsi-ld:ChargingSession:session-760876566
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 85:
#   ID: urn:ngsi-ld:ChargingSession:session-540427598
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 86:
#   ID: urn:ngsi-ld:ChargingSession:session-833440701
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 87:
#   ID: urn:ngsi-ld:ChargingSession:session-761016594
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 88:
#   ID: urn:ngsi-ld:ChargingSession:session-999988190
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 89:
#   ID: urn:ngsi-ld:ChargingSession:session-91822672
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 90:
#   ID: urn:ngsi-ld:ChargingSession:session-116530578
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 91:
#   ID: urn:ngsi-ld:ChargingSession:session-132758424
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 92:
#   ID: urn:ngsi-ld:ChargingSession:session-642709452
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 93:
#   ID: urn:ngsi-ld:ChargingSession:session-411933589
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 94:
#   ID: urn:ngsi-ld:ChargingSession:session-317765589
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 95:
#   ID: urn:ngsi-ld:ChargingSession:session-731508220
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 96:
#   ID: urn:ngsi-ld:ChargingSession:session-683401169
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 97:
#   ID: urn:ngsi-ld:ChargingSession:session-722944064
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 98:
#   ID: urn:ngsi-ld:ChargingSession:session-983546756
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 99:
#   ID: urn:ngsi-ld:ChargingSession:session-184258895
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 100:
#   ID: urn:ngsi-ld:ChargingSession:session-374016477
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 101:
#   ID: urn:ngsi-ld:ChargingSession:session-423862441
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 102:
#   ID: urn:ngsi-ld:ChargingSession:session-259453794
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 103:
#   ID: urn:ngsi-ld:ChargingSession:session-170411579
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 104:
#   ID: urn:ngsi-ld:ChargingSession:session-458101623
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 105:
#   ID: urn:ngsi-ld:ChargingSession:session-5275152
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 106:
#   ID: urn:ngsi-ld:ChargingSession:session-965558579
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 107:
#   ID: urn:ngsi-ld:ChargingSession:session-293059925
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 108:
#   ID: urn:ngsi-ld:ChargingSession:session-522933799
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 109:
#   ID: urn:ngsi-ld:ChargingSession:session-749460383
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 110:
#   ID: urn:ngsi-ld:ChargingSession:session-188973558
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 111:
#   ID: urn:ngsi-ld:ChargingSession:session-635221981
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 112:
#   ID: urn:ngsi-ld:ChargingSession:session-725103170
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 113:
#   ID: urn:ngsi-ld:ChargingSession:session-680798780
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 114:
#   ID: urn:ngsi-ld:ChargingSession:session-281252999
#   Type: ChargingSession
#   Attributes: 13
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 115:
#   ID: urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01
#   Type: ChargingPoint
#   Attributes: 7
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 116:
#   ID: urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01-S
#   Type: ChargingPointStatus
#   Attributes: 4
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 117:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-001_1751881256847
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 118:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-002_1751881256972
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 119:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-003_1751881257086
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 120:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-004_1751881257208
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 121:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-005_1751881257329
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 122:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-006_1751881257450
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 123:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-007_1751881257562
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 124:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-008_1751881257682
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 125:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-009_1751881257794
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 126:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-010_1751881257915
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 127:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-011_1751881258028
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 128:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-012_1751881258140
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 129:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-013_1751881258260
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 130:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-014_1751881258371
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 131:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-015_1751881258489
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 132:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-016_1751881258610
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 133:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-017_1751881258724
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 134:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-018_1751881258846
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 135:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-019_1751881258957
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
#
# Entity 136:
#   ID: urn:ngsi-ld:ChargingSessionTest:session-020_1751881259067
#   Type: ChargingSessionTest
#   Attributes: 5
#   Context: https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld
# [{'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingPointStatus:CP_001_S_001',
#   'type': 'ChargingPointStatus',
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime',
#     '@value': '2025-06-30T09:20:23.035642+00:00'}},
#   'operatingData': {'type': 'Property',
#    'value': {'currentPowerOutput': 0,
#     'currentVoltage': 230,
#     'currentCurrent': 0,
#     'powerFactor': 0.95,
#     'efficiency': 92.5}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:E4C-001-CP-001'},
#   'unitStatus': {'type': 'Property', 'value': 'available'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingPoint:E4C-001-CP-001',
#   'type': 'ChargingPoint',
#   'chargingType': {'type': 'Property', 'value': 'AC-Level2'},
#   'communicationProtocol': {'type': 'Property', 'value': 'OCPP1.6J'},
#   'connectorTypes': {'type': 'Property', 'value': 'Type2'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.711917Z'}},
#   'pointId': {'type': 'Property', 'value': 'CP-030-1-001'},
#   'powerCapabilities': {'type': 'Property',
#    'value': {'maxACPower': 22,
#     'maxDCPower': 0,
#     'maxVoltage': 400,
#     'maxCurrent': 32,
#     'phases': 3}},
#   'refChargingPointStatus': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPointStatus:E4C-001-CP-001-status-0001'},
#   'refChargingStation': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingStation:E4C-001'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:E-Vehicle:EV-001',
#   'type': 'E-Vehicle',
#   'batterySpecifications': {'type': 'Property',
#    'value': {'totalCapacity': 52,
#     'batteryType': 'lithium-ion',
#     'nominalVoltage': 400}},
#   'brand': {'type': 'Property', 'value': 'Renault'},
#   'chargingCapabilities': {'type': 'Property',
#    'value': {'maxChargingPowerAC': 22,
#     'maxChargingPowerDC': 130,
#     'chargingPortTypes': ['Type2', 'CCS2'],
#     'chargingStandards': ['AC-Level2', 'DC-FastCharging']}},
#   'color': {'type': 'Property', 'value': 'white'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.736270Z'}},
#   'refVehicleStatus': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:E-VehicleStatus:EV-001-status-0001'},
#   'vehiclePlateIdentifier': {'type': 'Property', 'value': 'EE-049-CE'},
#   'vehicleType': {'type': 'Property', 'value': 'car'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-512840826',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '1'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'chargingDuration': {'type': 'Property',
#    'value': 25,
#    'units': {'type': 'Property', 'value': 'MIN'}},
#   'chargingStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:34.759457Z'}},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759457Z'}},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759779Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:E4C-001-CP-001'},
#   'refVehicleStatus': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:E-VehicleStatus:vehicle-001-status'},
#   'sessionDuration': {'type': 'Property',
#    'value': 25.5,
#    'units': {'type': 'Property', 'value': 'MIN'}},
#   'sessionId': {'type': 'Property', 'value': '512840826'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759457Z'}},
#   'sessionStatus': {'type': 'Property', 'value': 'charging'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': 'RemoteApp'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingPointStatus:E4C-001-CP-001-S',
#   'type': 'ChargingPointStatus',
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime',
#     '@value': '2025-06-30T10:12:01.767990+00:00'}},
#   'operatingData': {'type': 'Property',
#    'value': {'currentPowerOutput': 11,
#     'currentVoltage': 400,
#     'currentCurrent': 16,
#     'powerFactor': 0.98,
#     'efficiency': 94}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:E4C-001-CP-001'},
#   'unitStatus': {'type': 'Property', 'value': 'charging'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-703497342',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-30T05:42:28+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value': 0.504,
#    'units': {'type': 'Property', 'value': 'kWh'},
#    'observedAt': '2025-05-30T05:44:44.000Z'},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T12:19:40.806764Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01'},
#   'sessionDuration': {'type': 'Property',
#    'value': 2.266667,
#    'units': {'type': 'Property', 'value': 'MIN'},
#    'observedAt': '2025-05-30T05:44:44.000Z'},
#   'sessionEndTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-30T05:44:44+00:00'},
#    'observedAt': '2025-05-30T05:44:44.000Z'},
#   'sessionId': {'type': 'Property', 'value': '703497342'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-30T05:42:28+00:00'},
#    'observedAt': '2025-05-30T05:42:28.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-412512340',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T22:34:44+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value': 2.401,
#    'units': {'type': 'Property', 'value': 'kWh'},
#    'observedAt': '2025-05-29T22:45:24.000Z'},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T12:19:40.808936Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01'},
#   'sessionDuration': {'type': 'Property',
#    'value': 10.666667,
#    'units': {'type': 'Property', 'value': 'MIN'},
#    'observedAt': '2025-05-29T22:45:24.000Z'},
#   'sessionEndTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T22:45:24+00:00'},
#    'observedAt': '2025-05-29T22:45:24.000Z'},
#   'sessionId': {'type': 'Property', 'value': '412512340'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T22:34:44+00:00'},
#    'observedAt': '2025-05-29T22:34:44.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-852888750',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T10:38:30+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value': 8.074,
#    'units': {'type': 'Property', 'value': 'kWh'},
#    'observedAt': '2025-05-29T11:27:56.000Z'},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T12:19:40.812819Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01'},
#   'sessionDuration': {'type': 'Property',
#    'value': 49.433333,
#    'units': {'type': 'Property', 'value': 'MIN'},
#    'observedAt': '2025-05-29T11:27:56.000Z'},
#   'sessionEndTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T11:27:56+00:00'},
#    'observedAt': '2025-05-29T11:27:56.000Z'},
#   'sessionId': {'type': 'Property', 'value': '852888750'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-29T10:38:30+00:00'},
#    'observedAt': '2025-05-29T10:38:30.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-718583992',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-28T17:00:49+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value':
},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-02-18T00:24:00.000Z'},
#    'observedAt': '2025-02-18T00:24:00.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'preparing'}}]

# %%
query_entity_by_id("urn:ngsi-ld:ChargingSession:session-512840826")
# Out:
# Status Code: 200
# {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#  'id': 'urn:ngsi-ld:ChargingSession:session-512840826',
#  'type': 'ChargingSession',
#  'refVehicleStatus': {'type': 'Relationship',
#   'object': 'urn:ngsi-ld:E-VehicleStatus:vehicle-001-status'},
#  'refChargingPoint': {'type': 'Relationship',
#   'object': 'urn:ngsi-ld:ChargingPoint:E4C-001-CP-001'},
#  'sessionId': {'type': 'Property', 'value': '512840826'},
#  'sessionStatus': {'type': 'Property', 'value': 'charging'},
#  'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#  'sessionStartTime': {'type': 'Property',
#   'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759457Z'}},
#  'chargingStartTime': {'type': 'Property',
#   'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:34.759457Z'}},
#  'sessionDuration': {'type': 'Property',
#   'value': 25.5,
#   'units': {'type': 'Property', 'value': 'MIN'}},
#  'chargingDuration': {'type': 'Property',
#   'value': 25,
#   'units': {'type': 'Property', 'value': 'MIN'}},
#  'userId': {'type': 'Property', 'value': 'RemoteApp'},
#  'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#  'authenticationId': {'type': 'Property', 'value': '1'},
#  'dateCreated': {'type': 'Property',
#   'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759457Z'}},
#  'lastUpdated': {'type': 'Property',
#   'value': {'@type': 'DateTime', '@value': '2025-06-30T11:21:04.759779Z'}}}

# %%
query_entities_by_type("ChargingStation")
# Out:
# Status Code: 200
# Found 0 entities of type 'ChargingStation'
# []

# %%
query_entities_by_attribute("sessionType", "AC-Level2")
# Out:
# Status Code: 200
# Query: sessionType=="AC-Level2"
# Found 10 entities with sessionType=AC-Level2
#
# Entity 1:
#   ID: urn:ngsi-ld:ChargingSession:session-512840826
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 2:
#   ID: urn:ngsi-ld:ChargingSession:session-703497342
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 3:
#   ID: urn:ngsi-ld:ChargingSession:session-412512340
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 4:
#   ID: urn:ngsi-ld:ChargingSession:session-852888750
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 5:
#   ID: urn:ngsi-ld:ChargingSession:session-718583992
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 6:
#   ID: urn:ngsi-ld:ChargingSession:session-155986737
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 7:
#   ID: urn:ngsi-ld:ChargingSession:session-487807670
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 8:
#   ID: urn:ngsi-ld:ChargingSession:session-528124502
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 9:
#   ID: urn:ngsi-ld:ChargingSession:session-840223019
#   Type: ChargingSession
#   sessionType: AC-Level2
#
# Entity 10:
#   ID: urn:ngsi-ld:ChargingSession:session-5101423
#   Type: ChargingSession
#   sessionType: AC-Level2
# [{'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session
},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-26T16:51:07+00:00'},
#    'observedAt': '2025-05-26T16:51:07.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-840223019',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-22T14:17:33+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value': 13.041,
#    'units': {'type': 'Property', 'value': 'kWh'},
#    'observedAt': '2025-05-23T20:52:16.000Z'},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T12:19:40.826296Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01'},
#   'sessionDuration': {'type': 'Property',
#    'value': 1834.716667,
#    'units': {'type': 'Property', 'value': 'MIN'},
#    'observedAt': '2025-05-23T20:52:16.000Z'},
#   'sessionEndTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-23T20:52:16+00:00'},
#    'observedAt': '2025-05-23T20:52:16.000Z'},
#   'sessionId': {'type': 'Property', 'value': '840223019'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-22T14:17:33+00:00'},
#    'observedAt': '2025-05-22T14:17:33.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}},
#  {'@context': 'https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld',
#   'id': 'urn:ngsi-ld:ChargingSession:session-5101423',
#   'type': 'ChargingSession',
#   'authenticationId': {'type': 'Property', 'value': '8E47015B'},
#   'authenticationMethod': {'type': 'Property', 'value': 'RFID'},
#   'dateCreated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-04-27T14:54:17+00:00'}},
#   'energyConsumed': {'type': 'Property',
#    'value': 8.108,
#    'units': {'type': 'Property', 'value': 'kWh'},
#    'observedAt': '2025-05-01T07:08:24.000Z'},
#   'lastUpdated': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-06-30T12:19:40.830790Z'}},
#   'refChargingPoint': {'type': 'Relationship',
#    'object': 'urn:ngsi-ld:ChargingPoint:ParisSaclay30-1-P-01'},
#   'sessionDuration': {'type': 'Property',
#    'value': 5294.116667,
#    'units': {'type': 'Property', 'value': 'MIN'},
#    'observedAt': '2025-05-01T07:08:24.000Z'},
#   'sessionEndTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-05-01T07:08:24+00:00'},
#    'observedAt': '2025-05-01T07:08:24.000Z'},
#   'sessionId': {'type': 'Property', 'value': '5101423'},
#   'sessionStartTime': {'type': 'Property',
#    'value': {'@type': 'DateTime', '@value': '2025-04-27T14:54:17+00:00'},
#    'observedAt': '2025-04-27T14:54:17.000Z'},
#   'sessionStatus': {'type': 'Property', 'value': 'ended'},
#   'sessionType': {'type': 'Property', 'value': 'AC-Level2'},
#   'userId': {'type': 'Property', 'value': '8E47015B'}}]

# %% [markdown]
# Headers:
# Content-Type: application/json
# Accept: application/ld+json
# Link: <https://raw.githubusercontent.com/chzh63315/DigiEV/refs/heads/main/contexts/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"
#
#
# query session duration > 500
#
# Get
#
# http://localhost:1026/ngsi-ld/v1/entities?type=ChargingSession&q=sessionDuration>500&limit=20
#
#
#
# http://localhost:8080/temporal/entities/?type=ChargingSession&timerel=after&timeAt=2024-12-31T23:59:59Z&timeproperty=observedAt&attrs=sessionStartTime&limit=20
#
# http://localhost:8080/temporal/entities/?type=ChargingSession&timerel=after&timeAt=2024-12-31T23:59:59Z&timeproperty=observedAt&attrs=energyConsumed&limit=20
#
# http://localhost:8080/temporal/entities/?type=ChargingSession&timerel=after&timeAt=2024-12-31T23:59:59Z&timeproperty=observedAt&attrs=energyConsumed,chargingDuration&limit=20
#
# http://localhost:8080/temporal/entities/?type=ChargingSession&timerel=between&timeAt=2025-03-01T00:00:00Z&endTimeAt=2025-05-31T23:59:59Z&timeproperty=observedAt&attrs=sessionEndTime&limit=100
